# %% [markdown]
# <a href="https://colab.research.google.com/github/imtiazhowlader99/Data-Science/blob/main/Homework_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome**

# %% [markdown]
# ## **First Homework**

# %%
print ('Hello, Welcome to Skillmorph')
# Out:
# Hello, Welcome to Skillmorph
